# %%
metrics = {'proactive': {'j10': {1: {'avg_makespan': [33.62407407407407, 29.58917197452229, 23.51489361702128, 18.808383233532933], 'avg_online_time': [0.0006148726851851, 0.0006080683629223, 0.0006174442615914, 0.0007122790742062], 'avg_offline_time': [0.0682512879371642, 0.0648653127585246, 0.0680067549360559, 0.0676609870202526]}, 2: {'avg_makespan': [42.24090909090909, 32.346278317152105, 27.129166666666663, 20.11023622047244], 'avg_online_time': [0.000570835308595, 0.0006084874224122, 0.0005917956431706, 0.0006537174615333], 'avg_offline_time': [0.0679234222932295, 0.0769405820223119, 0.0681111643711725, 0.0725715554605318]}}, 'j20': {1: {'avg_makespan': [53.57297297297297, 45.4070351758794, 28.58823529411765, 24.766233766233768], 'avg_online_time': [0.0014022582286112, 0.0015790306743065, 0.0017100342181549, 0.0020641599382672], 'avg_offline_time': [0.3107294417716361, 0.1058365975193042, 0.1180698490944228, 0.1139248903695638]}, 2: {'avg_makespan': [69.58928571428571, 45.68421052631579, 37.37096774193548, 24.410714285714285], 'avg_online_time': [0.0011991637093679, 0.001245451600928, 0.0015532682018894, 0.0019046877111706], 'avg_offline_time': [0.1043382712772913, 0.1069865932590082, 0.1111289858818053, 0.1181659059865133]}}}, 'reactive': {'j10': {1: {'avg_makespan': [30.09629629629629, 29.524475524475523, 23.3015873015873, 20.63636363636364], 'avg_online_time': [0.1496110863155788, 0.1636888213924594, 0.1170880189017643, 0.1225437684492631], 'avg_offline_time': [0.0682512879371642, 0.0648465056519407, 0.069360854133727, 0.0764348073439164]}, 2: {'avg_makespan': [34.481818181818184, 31.071005917159763, 26.794520547945204, 20.33333333333333], 'avg_online_time': [0.1669135202061046, 0.1379399003361808, 0.1490480213949124, 0.1413089434305826], 'avg_offline_time': [0.0679234222932295, 0.0801254489718103, 0.067332140386921, 0.0728003978729247]}}, 'j20': {1: {'avg_makespan': [50.19189189189189, 44.625, 24.0, 0], 'avg_online_time': [0.507118060782149, 0.5555919408798218, 0.4145941734313965, 0], 'avg_offline_time': [0.3107294417716361, 0.0978977978229522, 0.0806065797805786, 0]}, 2: {'avg_makespan': [62.43928571428572, 46.52, 49.0, 0], 'avg_online_time': [0.5701716635908399, 0.398417272567749, 0.5617902676264445, 0], 'avg_offline_time': [0.1043382712772913, 0.1026050662994384, 0.0858295758565266, 0]}}}, 'stnu': {'j10': {1: {'avg_makespan': [24.764814814814816, 26.1654501216545, 23.3632183908046, 23.96039603960396], 'avg_online_time': [0.0089052191487064, 0.0083850485855064, 0.0083983985857031, 0.009016976498141], 'avg_offline_time': [0.8996029884726913, 0.8349246468277163, 0.7826791368681809, 0.8046998186866836]}, 2: {'avg_makespan': [27.08636363636364, 26.354166666666668, 25.900343642611684, 27.74621212121212], 'avg_online_time': [0.0085156083106994, 0.008295429604394, 0.0084582940000028, 0.008734463742285], 'avg_offline_time': [0.895965389771895, 0.6429463404984701, 0.6867129368470707, 0.865239705100204]}}, 'j20': {1: {'avg_makespan': [41.18559556786703, 42.40996168582375, 33.358361774744026, 35.04577464788732], 'avg_online_time': [0.0333158666077082, 0.0298314195026382, 0.0315138032411958, 0.0327021706272178], 'avg_offline_time': [1.0990655699595189, 1.0431221828606851, 0.9818228560503024, 0.9775394612634686]}, 2: {'avg_makespan': [47.746428571428574, 40.01937984496124, 36.88695652173913, 39.44075829383886], 'avg_online_time': [0.0297940228666577, 0.0291308515755704, 0.0285452117090639, 0.0282146252727056], 'avg_offline_time': [1.0593344688415527, 1.0138586537782537, 0.8184943655262823, 0.9684553202859598]}}}} 
feasibility = {'proactive': {'j10': {'ALL': [1.0, 0.64375, 0.4615384615384615, 0.2161764705882353], 1: [1.0, 0.5233333333333333, 0.3671875, 0.2319444444444444], 2: [1.0, 0.64375, 0.4615384615384615, 0.1984375]}, 'j20': {'ALL': [1.0, 0.5066666666666667, 0.3351351351351351, 0.1220183486238532], 1: [1.0, 0.4422222222222222, 0.2428571428571428, 0.1327586206896551], 2: [1.0, 0.5066666666666667, 0.3351351351351351, 0.1098039215686274]}}, 'reactive': {'j10': {'ALL': [1.0, 0.3520833333333333, 0.1403846153846153, 0.0125], 1: [1.0, 0.2383333333333333, 0.0984375, 0.0152777777777777], 2: [1.0, 0.3520833333333333, 0.1403846153846153, 0.009375]}, 'j20': {'ALL': [1.0, 0.0833333333333333, 0.0162162162162162, 0.0], 1: [1.0, 0.0177777777777777, 0.0040816326530612, 0.0], 2: [1.0, 0.0833333333333333, 0.0162162162162162, 0.0]}}, 'stnu': {'j10': {'ALL': [1.0, 0.6461538461538462, 0.5290909090909091, 0.4840579710144927], 1: [1.0, 0.6227272727272727, 0.6492537313432836, 0.5771428571428572], 2: [1.0, 0.6461538461538462, 0.5290909090909091, 0.388235294117647]}, 'j20': {'ALL': [1.0, 0.80625, 0.6216216216216216, 0.4669811320754717], 1: [1.0, 0.54375, 0.5745098039215686, 0.4982456140350877], 2: [1.0, 0.80625, 0.6216216216216216, 0.4306122448979592]}}}

# %%
# Data
modes = ["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"]
# Noise factor 1
# j10
stnu_avg_makespan_1_j10 = metrics['stnu']['j10'][1]['avg_makespan']
reactive_avg_makespan_1_j10 = metrics['reactive']['j10'][1]['avg_makespan']
proactive_avg_makespan_1_j10 = metrics['proactive']['j10'][1]['avg_makespan']
# j20
stnu_avg_makespan_1_j20 = metrics['stnu']['j20'][1]['avg_makespan']
reactive_avg_makespan_1_j20 = metrics['reactive']['j20'][1]['avg_makespan']
proactive_avg_makespan_1_j20 = metrics['proactive']['j20'][1]['avg_makespan']
# Noise factor 2
# j10
stnu_avg_makespan_2_j10 = metrics['stnu']['j10'][2]['avg_makespan']
reactive_avg_makespan_2_j10 = metrics['reactive']['j10'][2]['avg_makespan']
proactive_avg_makespan_2_j10 = metrics['proactive']['j10'][2]['avg_makespan']
# j20
stnu_avg_makespan_2_j20 = metrics['stnu']['j20'][2]['avg_makespan']
reactive_avg_makespan_2_j20 = metrics['reactive']['j20'][2]['avg_makespan']
proactive_avg_makespan_2_j20 = metrics['proactive']['j20'][2]['avg_makespan']
# Feasibility
feasibility_j10 = {
    "stnu": feasibility['stnu']['j10']['ALL'],
    "reactive": feasibility['reactive']['j10']['ALL'],
    "proactive": feasibility['proactive']['j10']['ALL']
}
feasibility_j20 = {
    "stnu": feasibility['stnu']['j20']['ALL'],
    "reactive": feasibility['reactive']['j20']['ALL'],
    "proactive": feasibility['proactive']['j20']['ALL']
}
# Average online time
avg_online_time_j10_1 = {
    "stnu": metrics['stnu']['j10'][1]['avg_online_time'],
    "reactive": metrics['reactive']['j10'][1]['avg_online_time'],
    "proactive": metrics['proactive']['j10'][1]['avg_online_time']
}
avg_online_time_j20_1 = {
    "stnu": metrics['stnu']['j20'][1]['avg_online_time'],
    "reactive": metrics['reactive']['j20'][1]['avg_online_time'],
    "proactive": metrics['proactive']['j20'][1]['avg_online_time']
}
avg_online_time_j10_2 = {
    "stnu": metrics['stnu']['j10'][2]['avg_online_time'],
    "reactive": metrics['reactive']['j10'][2]['avg_online_time'],
    "proactive": metrics['proactive']['j10'][2]['avg_online_time']
}
avg_online_time_j20_2 = {
    "stnu": metrics['stnu']['j20'][2]['avg_online_time'],
    "reactive": metrics['reactive']['j20'][2]['avg_online_time'],
    "proactive": metrics['proactive']['j20'][2]['avg_online_time']
}
# Average offline time
avg_offline_time_j10_1 = {
    "stnu": metrics['stnu']['j10'][1]['avg_offline_time'],
    "reactive": metrics['reactive']['j10'][1]['avg_offline_time'],
    "proactive": metrics['proactive']['j10'][1]['avg_offline_time']
}
avg_offline_time_j20_1 = {
    "stnu": metrics['stnu']['j20'][1]['avg_offline_time'],
    "reactive": metrics['reactive']['j20'][1]['avg_offline_time'],
    "proactive": metrics['proactive']['j20'][1]['avg_offline_time']
}
avg_offline_time_j10_2 = {
    "stnu": metrics['stnu']['j10'][2]['avg_offline_time'],
    "reactive": metrics['reactive']['j10'][2]['avg_offline_time'],
    "proactive": metrics['proactive']['j10'][2]['avg_offline_time']
}
avg_offline_time_j20_2 = {
    "stnu": metrics['stnu']['j20'][2]['avg_offline_time'],
    "reactive": metrics['reactive']['j20'][2]['avg_offline_time'],
    "proactive": metrics['proactive']['j20'][2]['avg_offline_time']
}
# Feasibility for noise factor 1
feasibility_j10_1 = {
    "stnu": feasibility['stnu']['j10'][1],
    "reactive": feasibility['reactive']['j10'][1],
    "proactive": feasibility['proactive']['j10'][1]
}
# Feasibility for noise factor 2
feasibility_j20_1 = {
    "stnu": feasibility['stnu']['j20'][1],
    "reactive": feasibility['reactive']['j20'][1],
    "proactive": feasibility['proactive']['j20'][1]
}
# Feasibility for noise factor 2
feasibility_j10_2 = {
    "stnu": feasibility['stnu']['j10'][2],
    "reactive": feasibility['reactive']['j10'][2],
    "proactive": feasibility['proactive']['j10'][2]
}
# Feasibility for noise factor 2
feasibility_j20_2 = {
    "stnu": feasibility['stnu']['j20'][2],
    "reactive": feasibility['reactive']['j20'][2],
    "proactive": feasibility['proactive']['j20'][2]
}

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_feasibility_and_makespan(x_vals, feasibility_data, makespan_data,
                                  title_prefix="STNU-based hybrid approach"):
    """
    Plots feasibility ratio and average makespan side by side for a given approach.

    Parameters:
    - x_vals: list of float (e.g. [1, 0.9, 0.75, 0.5]) – quantiles or x-axis values
    - feasibility_data: list of float – feasibility ratio values
    - makespan_data: list of float – average makespan values
    - title_prefix: str – descriptive prefix for subplot titles
    """
    x_labels = [str(x) for x in x_vals]

    # Set the figure size
    plt.figure(figsize=(12, 6))

    # Feasibility Ratio Plot
    plt.subplot(1, 2, 1)
    plt.plot(x_vals, feasibility_data, marker='o', color='skyblue', linestyle='-', alpha=0.7)
    plt.title(f'Feasibility Ratio of {title_prefix}')
    plt.xlabel('Quantile')
    plt.ylabel('Feasibility Ratio')
    plt.ylim(0, 1)
    plt.xticks(x_vals, x_labels)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    for x, y in zip(x_vals, feasibility_data):
        plt.text(x, y - 0.05, f"{y:.2f}", ha='center', va='bottom')

    # Average Makespan Plot
    plt.subplot(1, 2, 2)
    plt.plot(x_vals, makespan_data, marker='o', color='salmon', linestyle='-', alpha=0.7)
    plt.title(f'Average Makespan of {title_prefix}')
    plt.xlabel('Quantile')
    plt.ylabel('Average Makespan')
    plt.ylim(0, max(makespan_data) * 1.1)
    plt.xticks(x_vals, x_labels)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    for x, y in zip(x_vals, makespan_data):
        plt.text(x, y + 0.5, f"{y:.2f}", ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_grouped_bars(metrics_dict, modes, method_names, colors, title="Comparison Across Modes"):
    """
    Plots grouped bar charts for multiple metrics across different scheduling methods.

    Parameters:
    - metrics_dict: dict[str, list[list[float]]]
        Dictionary where keys are metric names and values are lists of method-specific data.
    - modes: list[str]
        Labels for the x-axis (e.g., ["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"])
    - method_names: list[str]
        Names of the methods (e.g., ["Proactive", "Reactive", "STNU"])
    - colors: list[str]
        Color for each method (must match length of method_names)
    - title: str
        Title for the full figure
    """
    num_metrics = len(metrics_dict)
    x = np.arange(len(modes))
    bar_width = 0.25

    fig, axs = plt.subplots(2, 2, figsize=(14, 10))
    axs = axs.flatten()

    for i, (metric_name, data_lists) in enumerate(metrics_dict.items()):
        ax = axs[i]
        for j, (method_data, method) in enumerate(zip(data_lists, method_names)):
            ax.bar(x + j * bar_width, method_data, bar_width,
                   label=method, color=colors[j], alpha=0.8)

        ax.set_title(metric_name)
        ax.set_xticks(x + bar_width)
        ax.set_xticklabels(modes, rotation=15)
        ax.set_xlabel("Mode")
        ax.set_ylabel(metric_name)
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        ax.legend()

    plt.suptitle(title, fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_line_metrics(x_vals, modes, metrics, method_names, colors, markers, title="Line Plot Comparison"):
    """
    Plots line graphs for multiple metrics across methods and quantile modes.

    Parameters:
    - x_vals: list[float] – numeric quantile values (e.g. [1.0, 0.9, 0.75, 0.5])
    - modes: list[str] – labels for the x-axis (e.g. ["robust", "quantile_0.9", ...])
    - metrics: dict[str, list[list[float]]] – keys are metric names, values are lists of method-specific values
    - method_names: list[str] – method labels (e.g. ["Proactive", "Reactive", "STNU"])
    - colors: list[str] – line colors for each method
    - markers: list[str] – marker styles for each method
    - title: str – plot title
    """
    fig, axs = plt.subplots(2, 2, figsize=(14, 10))
    axs = axs.flatten()

    for i, (metric_name, data_lists) in enumerate(metrics.items()):
        ax = axs[i]
        for j, (method_data, method) in enumerate(zip(data_lists, method_names)):
            ax.plot(x_vals, method_data, label=method, marker=markers[j], color=colors[j], linewidth=2)

        ax.set_title(metric_name)
        ax.set_xticks(x_vals)
        ax.set_xticklabels(modes)
        ax.set_xlabel("Mode")
        ax.set_ylabel(metric_name)
        ax.grid(True, linestyle='--', alpha=0.5)
        ax.legend()

    plt.suptitle(title, fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def compare_datasets_bar_chart(metrics_data, categories, group_labels, title="Comparison Across Settings"):
    """
    Plots a grouped bar chart to compare multiple metrics across different datasets/settings.

    Parameters:
    - metrics_data: dict[str, list[list[float]]]
        A dictionary mapping metric names (e.g., "Makespan") to a list of lists,
        where each inner list corresponds to values for one group (e.g., noise factor 1, noise factor 2).
    - categories: list[str]
        The labels on the x-axis (e.g., ["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"]).
    - group_labels: list[str]
        Labels for the dataset groups (e.g., ["Noise Factor 1", "Noise Factor 2"]).
    - title: str
        Title for the overall figure.
    """
    num_groups = len(group_labels)
    num_categories = len(categories)
    x = np.arange(num_categories)
    bar_width = 0.8 / num_groups

    colors = plt.cm.tab10.colors  # up to 10 distinguishable colors

    fig, axs = plt.subplots(1, len(metrics_data), figsize=(6 * len(metrics_data), 6))

    if len(metrics_data) == 1:
        axs = [axs]  # make iterable if only one subplot

    for ax, (metric_name, datasets) in zip(axs, metrics_data.items()):
        for i, (data, label) in enumerate(zip(datasets, group_labels)):
            ax.bar(x + i * bar_width, data, bar_width, label=label, color=colors[i % len(colors)], alpha=0.85)

        ax.set_title(metric_name)
        ax.set_xticks(x + bar_width * (num_groups - 1) / 2)
        ax.set_xticklabels(categories, rotation=15)
        ax.set_xlabel("Mode")
        ax.set_ylabel(metric_name)
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        ax.legend()

    plt.suptitle(title, fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

import matplotlib.pyplot as plt
import numpy as np

def compare_datasets_line_plot(metrics_data, x_vals, x_labels, group_labels, title="Line Plot Comparison Across Settings"):
    """
    Plots line graphs to compare multiple datasets across different metrics.

    Parameters:
    - metrics_data: dict[str, list[list[float]]]
        Dictionary where each key is a metric name (e.g., "Avg Makespan") and each value is a list of lists.
        Each inner list represents data for one group (e.g., Noise Factor 1, Noise Factor 2).
    - x_vals: list[float]
        Numeric x-axis values (e.g., [1.0, 0.9, 0.75, 0.5]).
    - x_labels: list[str]
        Labels for the x-axis ticks (e.g., ["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"]).
    - group_labels: list[str]
        Names of the datasets being compared (e.g., ["Noise Factor 1", "Noise Factor 2"]).
    - title: str
        Title for the entire figure.
    """
    num_groups = len(group_labels)
    colors = plt.cm.tab10.colors
    markers = ['o', 's', '^', 'D', '*', 'x', 'P', 'v']

    fig, axs = plt.subplots(1, len(metrics_data), figsize=(6 * len(metrics_data), 5))

    if len(metrics_data) == 1:
        axs = [axs]  # Ensure axs is iterable

    for ax, (metric_name, data_lists) in zip(axs, metrics_data.items()):
        for i, (data, label) in enumerate(zip(data_lists, group_labels)):
            ax.plot(x_vals, data, label=label,
                    marker=markers[i % len(markers)],
                    color=colors[i % len(colors)],
                    linewidth=2)

        ax.set_title(metric_name)
        ax.set_xticks(x_vals)
        ax.set_xticklabels(x_labels, rotation=15)
        ax.set_xlabel("Mode")
        ax.set_ylabel(metric_name)
        ax.grid(True, linestyle='--', alpha=0.5)
        ax.legend()

    plt.suptitle(title, fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
plot_feasibility_and_makespan(
    x_vals=[1, 0.9, 0.75, 0.5],
    feasibility_data=feasibility_j10_1['stnu'],
    makespan_data=stnu_avg_makespan_1_j10,
    title_prefix="STNU-based approach (Noise Factor 1)"
)

plot_feasibility_and_makespan(
    x_vals=[1, 0.9, 0.75, 0.5],
    feasibility_data=feasibility_j10_2['stnu'],
    makespan_data=stnu_avg_makespan_2_j10,
    title_prefix="STNU-based approach (Noise Factor 2)"
)

# %%
# -*- coding: utf-8 -*-
# Plot grouped line graphs for average makespan, feasibility, and online/offline times
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Average Makespan": [
            proactive_avg_makespan_1_j10,
            reactive_avg_makespan_1_j10,
            stnu_avg_makespan_1_j10
        ],
        "Feasibility Ratio": [
            feasibility_j10_1['proactive'],
            feasibility_j10_1['reactive'],
            feasibility_j10_1['stnu']
        ],
        "Average Online Time": [
            avg_online_time_j10_1['proactive'],
            avg_online_time_j10_1['reactive'],
            avg_online_time_j10_1['stnu']
        ],
        "Average Offline Time": [
            avg_offline_time_j10_1['proactive'],
            avg_offline_time_j10_1['reactive'],
            avg_offline_time_j10_1['stnu']
        ]
    },
    method_names=["Proactive", "Reactive", "STNU"],
    colors=["blue", "orange", "green"],
    markers=["o", "s", "^"],
    title="Comparison of Scheduling Methods for j10 (Noise Factor 1)"
)
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Average Makespan": [
            proactive_avg_makespan_2_j10,
            reactive_avg_makespan_2_j10,
            stnu_avg_makespan_2_j10
        ],
        "Feasibility Ratio": [
            feasibility_j10_2['proactive'],
            feasibility_j10_2['reactive'],
            feasibility_j10_2['stnu']
        ],
        "Average Online Time": [
            avg_online_time_j10_2['proactive'],
            avg_online_time_j10_2['reactive'],
            avg_online_time_j10_2['stnu']
        ],
        "Average Offline Time": [
            avg_offline_time_j10_2['proactive'],
            avg_offline_time_j10_2['reactive'],
            avg_offline_time_j10_2['stnu']
        ]
    },
    method_names=["Proactive", "Reactive", "STNU"],
    colors=["blue", "orange", "green"],
    markers=["o", "s", "^"],
    title="Comparison of Scheduling Methods for j10 (Noise Factor 2)"
)
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Average Makespan": [
            proactive_avg_makespan_1_j20,
            reactive_avg_makespan_1_j20,
            stnu_avg_makespan_1_j20
        ],
        "Feasibility Ratio": [
            feasibility_j20_1['proactive'],
            feasibility_j20_1['reactive'],
            feasibility_j20_1['stnu']
        ],
        "Average Online Time": [
            avg_online_time_j20_1['proactive'],
            avg_online_time_j20_1['reactive'],
            avg_online_time_j20_1['stnu']
        ],
        "Average Offline Time": [
            avg_offline_time_j20_1['proactive'],
            avg_offline_time_j20_1['reactive'],
            avg_offline_time_j20_1['stnu']
        ]
    },
    method_names=["Proactive", "Reactive", "STNU"],
    colors=["blue", "orange", "green"],
    markers=["o", "s", "^"],
    title="Comparison of Scheduling Methods for j20 (Noise Factor 1)"
)
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Average Makespan": [
            proactive_avg_makespan_2_j20,
            reactive_avg_makespan_2_j20,
            stnu_avg_makespan_2_j20
        ],
        "Feasibility Ratio": [
            feasibility_j20_2['proactive'],
            feasibility_j20_2['reactive'],
            feasibility_j20_2['stnu']
        ],
        "Average Online Time": [
            avg_online_time_j20_2['proactive'],
            avg_online_time_j20_2['reactive'],
            avg_online_time_j20_2['stnu']
        ],
        "Average Offline Time": [
            avg_offline_time_j20_2['proactive'],
            avg_offline_time_j20_2['reactive'],
            avg_offline_time_j20_2['stnu']
        ]
    },
    method_names=["Proactive", "Reactive", "STNU"],
    colors=["blue", "orange", "green"],
    markers=["o", "s", "^"],
    title="Comparison of Scheduling Methods for j20 (Noise Factor 2)"
)

# %%
# Do the above graphing but in each graph only include one method and both noise factors
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Avg Makespan": [proactive_avg_makespan_1_j10, proactive_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['proactive'], avg_online_time_j20['proactive']],
        "Avg Offline Time": [avg_offline_time_j10['proactive'], avg_offline_time_j20['proactive']],
        "Feasibility Ratio": [feasibility_j10_1['proactive'], feasibility_j10_2['proactive']],
    },
    method_names=["Proactive (Noise Factor 1)", "Proactive (Noise Factor 2)"],
    colors=["#1f77b4", "#ff7f0e"],
    markers=['o', 's'],
    title="Proactive Method Comparison for j10 and j20"
)
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Avg Makespan": [reactive_avg_makespan_1_j10, reactive_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['reactive'], avg_online_time_j20['reactive']],
        "Avg Offline Time": [avg_offline_time_j10['reactive'], avg_offline_time_j20['reactive']],
        "Feasibility Ratio": [feasibility_j10_1['reactive'], feasibility_j20_1['reactive']],
    },
    method_names=["Reactive (Noise Factor 1)", "Reactive (Noise Factor 2)"],
    colors=["#1f77b4", "#ff7f0e"],
    markers=['o', 's'],
    title="Reactive Method Comparison for j10 and j20"
)
plot_line_metrics(
    x_vals=[1, 0.9, 0.75, 0.5],
    modes=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    metrics={
        "Avg Makespan": [stnu_avg_makespan_1_j10, stnu_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['stnu'], avg_online_time_j20['stnu']],
        "Avg Offline Time": [avg_offline_time_j10['stnu'], avg_offline_time_j20['stnu']],
        "Feasibility Ratio": [feasibility_j10_1['stnu'], feasibility_j20_1['stnu']],
    },
    method_names=["STNU (Noise Factor 1)", "STNU (Noise Factor 2)"],
    colors=["#1f77b4", "#ff7f0e"],
    markers=['o', 's'],
    title="STNU Method Comparison for j10 and j20"
)
compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [proactive_avg_makespan_1_j10, proactive_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['proactive'], avg_online_time_j20['proactive']],
        "Avg Offline Time": [avg_offline_time_j10['proactive'], avg_offline_time_j20['proactive']],
        "Feasibility Ratio": [feasibility_j10_1['proactive'], feasibility_j20_1['proactive']],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="Proactive Method Comparison for j10 and j20"
)
compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [reactive_avg_makespan_1_j10, reactive_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['reactive'], avg_online_time_j20['reactive']],
        "Avg Offline Time": [avg_offline_time_j10['reactive'], avg_offline_time_j20['reactive']],
        "Feasibility Ratio": [feasibility_j10_1['reactive'], feasibility_j20_1['reactive']],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="Reactive Method Comparison for j10 and j20"
)
compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [stnu_avg_makespan_1_j10, stnu_avg_makespan_2_j10],
        "Avg Online Time": [avg_online_time_j10['stnu'], avg_online_time_j20['stnu']],
        "Avg Offline Time": [avg_offline_time_j10['stnu'], avg_offline_time_j20['stnu']],
        "Feasibility Ratio": [feasibility_j10_1['stnu'], feasibility_j20_1['stnu']],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="STNU Method Comparison for j10 and j20"
)

# %%
# -*- coding: utf-8 -*-
# Plot grouped bar charts for all metrics also grouped by noise factor so that each graph has one bar for each method while including both instances
compare_datasets_bar_chart(
    metrics_data={
        "Average Makespan": [proactive_avg_makespan_1_j10, reactive_avg_makespan_1_j10, stnu_avg_makespan_1_j10],
        "Average Online Time": [avg_online_time_j10['proactive'], avg_online_time_j10['reactive'], avg_online_time_j10['stnu']],
        "Average Offline Time": [avg_offline_time_j10['proactive'], avg_offline_time_j10['reactive'], avg_offline_time_j10['stnu']],
        "Feasibility Ratio": [feasibility_j10_1['proactive'], feasibility_j10_1['reactive'], feasibility_j10_1['stnu']],
    },
    categories=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1"],
    title="Comparison of Methods for j10 (Noise Factor 1)"
)

# %%
compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [proactive_avg_makespan_1, proactive_avg_makespan_2],
        "Avg Online Time": [proactive_avg_online_time_1, proactive_avg_online_time_2],
        "Avg Offline Time": [proactive_avg_offline_time_1, proactive_avg_offline_time_2],
        "Feasibility Ratio": [proactive_feasibility_ratio_1, proactive_feasibility_ratio_2],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="Proactive Approach Comparison"
)

compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [reactive_avg_makespan_1, reactive_avg_makespan_2],
        "Avg Online Time": [reactive_avg_online_time_1, reactive_avg_online_time_2],
        "Avg Offline Time": [reactive_avg_offline_time_1, reactive_avg_offline_time_2],
        "Feasibility Ratio": [reactive_feasibility_ratio_1, reactive_feasibility_ratio_2],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="Reactive Approach Comparison"
)

compare_datasets_line_plot(
    metrics_data={
        "Avg Makespan": [stnu_avg_makespan_1, stnu_avg_makespan_2],
        "Avg Online Time": [stnu_avg_online_time_1, stnu_avg_online_time_2],
        "Avg Offline Time": [stnu_avg_offline_time_1, stnu_avg_offline_time_2],
        "Feasibility Ratio": [stnu_feasibility_ratio_1, stnu_feasibility_ratio_2],
    },
    x_vals=[1, 0.9, 0.75, 0.5],
    x_labels=["robust", "quantile_0.9", "quantile_0.75", "quantile_0.5"],
    group_labels=["Noise Factor 1", "Noise Factor 2"],
    title="STNU-based Approach Comparison"
)
